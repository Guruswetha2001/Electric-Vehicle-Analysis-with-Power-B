# %% [markdown]
# <a href="https://colab.research.google.com/github/Guruswetha2001/Electric-Vehicle-Analysis-with-Power-B/blob/main/laptop_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
sns.set()

# %%
#data set
laptop = pd.read_csv('laptop_data.csv')

# %%
#  It will show the first 10 rows of the laptop DataFrame
laptop.head(10)
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5           5    Acer   Notebook    15.6                            1366x768
# 6           6   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 7           7   Apple  Ultrabook    13.3                            1440x900
# 8           8    Asus  Ultrabook    14.0                   Full HD 1920x1080
# 9           9    Acer  Ultrabook    14.0         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# ...

# %%
#It  will show the last 10 rows of the laptop DataFrame
laptop.tail(10)
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1293        1293  Lenovo            Notebook    15.6
# 1294        1294      HP            Notebook    15.6
# 1295        1295    Dell            Notebook    15.6
# 1296        1296      HP             Netbook    11.6
# 1297        1297    Asus            Notebook    15.6
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1293                 IPS Panel Full HD 1920x1080
# 1294                           Full HD 1920x1080
# 1295                                    1366x768
# 1296                                    1366x768
# 1297                                    1366x768
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
# Display the number of rows and colunms in data frame
laptop.shape
# Out:
# (1303, 12)

# %%
# it will show the DataFrame's structure
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
# It will shows the list of column names in dataframe
laptop.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Company',
#  'TypeName',
#  'Inches',
#  'ScreenResolution',
#  'Cpu',
#  'Ram',
#  'Memory',
#  'Gpu',
#  'OpSys',
#  'Weight',
#  'Price']

# %%
# It is used to check for missing (null) values in the DataFrame
laptop.isnull()
# Out:
#       Unnamed: 0  Company  TypeName  Inches  ScreenResolution    Cpu    Ram  \
# 0          False    False     False   False             False  False  False
# 1          False    False     False   False             False  False  False
# 2          False    False     False   False             False  False  False
# 3          False    False     False   False             False  False  False
# 4          False    False     False   False             False  False  False
# ...          ...      ...       ...     ...               ...    ...    ...
# 1298       False    False     False   False             False  False  False
# 1299       False    False     False   False             False  False  False
# 1300       False    False     False   False             False  False  False
# 1301       False    False     False   False             False  False  False
# 1302       False    False     False   False             False  False  False
#
#       Memory    Gpu  OpSys  Weight  Price
# ...

# %%
#This code is used to count the number of missing (null) values in each column of the DataFrame.
laptop.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#installing missing numbers
pip install missingno

# %%
#This code used to visually inspect the missing data in a DataFrame (laptop) using the missingno library.
import missingno as msno
msno.matrix(laptop)
# Out:
# <Axes: >

# %%
#display the number of rows and columns in dataframe
laptop.shape
# Out:
# (1303, 12)

# %%
#Display the numeric columns
laptop.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
#Display the string columns
laptop.describe(include='O')
# Out:
#        Company  TypeName   ScreenResolution                         Cpu   Ram  \
# count     1303      1303               1303                        1303  1303
# unique      19         6                 40                         118     9
# top       Dell  Notebook  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# freq       297       727                507                         190   619
#
#            Memory                    Gpu       OpSys Weight
# count        1303                   1303        1303   1303
# unique         39                    110           9    179
# top     256GB SSD  Intel HD Graphics 620  Windows 10  2.2kg
# freq          412                    281        1072    121

# %%
## Count Plot for the Company column, visualizing the number of laptops per company
sns.countplot(y=laptop['Company'], order=laptop['Company'].value_counts().index, palette='viridis')
plt.title('Number of Laptops by Company')
plt.xlabel('Count')
plt.ylabel('Company')
plt.show()

# %%
#Heat map  primary storage by company
import matplotlib.pyplot as plt
import seaborn as sns

# Count occurrences of each CPU company and storage type combination
storage_count = df.groupby(['CPU Company', 'Storage Type']).size().unstack(fill_value=0)

# Plot the data using seaborn's heatmap for better visualization
plt.figure(figsize=(8, 6))
sns.heatmap(storage_count, annot=True, cmap='Blues', fmt='d')

# Add labels and title
plt.title('Primary Storage by CPU Company for Laptops')
plt.xlabel('Storage Type')
plt.ylabel('CPU Company')

# Display the plot
plt.show()

# %%
#bar plot price by company
import matplotlib.pyplot as plt

# Create a bar plot

plt.figure(figsize=(10, 6))
plt.bar(companies, prices, color='skyblue')

# Add labels and title
plt.xlabel('Laptop company')
plt.ylabel('Price in USD')
plt.title('Laptop Prices by company')

# Display the plot
plt.show()

# %%
#bar plot laptop weight by company
import matplotlib.pyplot as plt

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(companies, weights, color='lightgreen')

# Add labels and title
plt.xlabel('Laptop company')
plt.ylabel('Weight (kg)')
plt.title('Laptop Weights by company')

# Display the plot
plt.show()

# %%
#Scatter plot company by ram size
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='RAM', y='Brand', data=laptop, s=100, hue='Brand', palette='Set2', marker='o')

# Add titles and labels
plt.title(' Company by RAM Size', fontsize=16)
plt.xlabel('RAM Size (GB)', fontsize=12)
plt.ylabel('Company (Brand)', fontsize=12)

# Show the plot
plt.show()
